# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style
df=pd.read_csv('spike_signal.csv')
spiky=df['Signal'].values
signal=np.array(spiky)
spiky=abs(signal)
len(spiky)
spiky.shape
# Out:
# (1000,)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style
df=pd.read_csv('spike_signal.csv')
spiky=df['Signal'].values
signal=np.array(signal)
spiky=abs(signal)
len(spiky)
spiky.shape
plt.figure(figsize=(20,12))
style.use('dark_background')
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.plot(spiky,'r',label='signal with spikes')
plt.legend(fontsize=20)
plt.show()
