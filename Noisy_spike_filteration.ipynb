# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style
spiky=pd.read_csv('spiky_signal_5000x1.csv')
signal=np.array(spiky)
spiky=abs(signal)
len(spiky)
spiky.shape
# Out:
# (4999, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style
spiky=pd.read_csv('spiky_signal_5000x1.csv')
signal=np.array(spiky)
spiky=abs(signal)
len(spiky)
spiky.shape
plt.figure(figsize=(20,12))
style.use('dark_background')
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.plot(spiky,'c' ,label='signal with spikes')
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(spiky,50)
plt.show()

# %%
a=np.array([1,2,3,4,5,16,17,27,38,99,100])
print(a)
print(a.shape)
b=np.where(a>5)
print(b)
# Out:
# [  1   2   3   4   5  16  17  27  38  99 100]
# (11,)
# (array([ 5,  6,  7,  8,  9, 10], dtype=int64),)

# %%
aa=np.array([1,2,3,4,5,16,27,38,99,100]).reshape(-1,1)
print(aa)
print(aa.shape)
bb=np.where(aa>5)[0]
print(bb)
# Out:
# [[  1]
#  [  2]
#  [  3]
#  [  4]
#  [  5]
#  [ 16]
#  [ 27]
#  [ 38]
#  [ 99]
#  [100]]
# (10, 1)
# [5 6 7 8 9]

# %%
len(bb)
# Out:
# 2

# %%
threshold=1
ultra_thresh=np.where(spiky>threshold)[0]
ultra_thresh
# Out:
# array([   7,   81,  167,  328,  333,  359,  466,  651,  783,  922,  971,
#        1001, 1030, 1040, 1073, 1146, 1182, 1183, 1237, 1259, 1270, 1299,
#        1405, 1419, 1459, 1631, 1653, 1698, 1717, 1731, 1811, 1920, 2139,
#        2143, 2168, 2278, 2356, 2425, 2442, 2459, 2471, 2508, 2658, 2667,
#        2742, 2751, 2873, 2914, 3045, 3132, 3175, 3195, 3245, 3260, 3263,
#        3279, 3383, 3420, 3443, 3454, 3500, 3580, 3604, 3642, 3816, 3826,
#        3862, 3898, 3929, 4030, 4040, 4108, 4113, 4198, 4199, 4216, 4229,
#        4254, 4274, 4296, 4413, 4460, 4472, 4496, 4516, 4520, 4568, 4586,
#        4611, 4647, 4702, 4708, 4721, 4735, 4762, 4796, 4820, 4856, 4888,
#        4911], dtype=int64)

# %%
filtered_sig=np.copy(spiky)
N=100
for ii in range(0,ultra_thresh.shape[0]):
    filtered_sig[ultra_thresh[ii]]=np.median(spiky[ultra_thresh[ii]:ultra_thresh[ii]+N])
plt.figure(figsize=(20,10))
style.use('dark_background')
plt.rcParams['xtick.labelsize']=25
plt.rcParams['ytick.labelsize']=25
plt.subplot(2,1,1)
plt.plot(spiky,'r',label='Clean-signal')
plt.xlabel('Time in sec',fontsize=15)
plt.ylabel('Amplitude',fontsize=15)
plt.title('Spiky-signal')
plt.legend()
plt.subplot(2,1,2)
plt.plot(filtered_sig,'b',label='Noisy-signal')
plt.xlabel('Time in sec',fontsize=15)
plt.ylabel('Amplitude',fontsize=15)
plt.title('filtered-signal')
plt.legend()
